# %% [markdown]
# # Guide to Install Python and Required Modules
#
# ## Step 1: Install Anaconda
# 1. Setup python by installing Anaconda: [https://www.anaconda.com/download](https://www.anaconda.com/download).
# 2. Follow the installation instructions for your operating system.
#
# ## Step 2: Setup a anaconda environment
# 1. After installation, you can use the `conda` command to manage environments and packages.
# 2. To create a new environment using Python 3.12.3 named `VDKI-Projekt`, run the following command in your terminal or command prompt:

# %%
conda create --name VDKI-Projekt python=3.12.3

# %% [markdown]
# 3. Activate the environment using:

# %%
conda activate VDKI-Projekt

# %% [markdown]
# ## Step 3: Install Required Modules
# To install Python modules, you can run the script below. Be sure to allow the install of the ipynb-kernel within visual studio.

# %%
print("Lets run a line, visual studio will now ask you to install the ipynb-package")
# Out:
# Lets run a line, visual studio will now ask you to install the ipynb-package

# %% [markdown]
# ## Step 4: Verify Installation
# To verify that all required modules are installed we run the following python code below:
# ```python
# import <module_name>
# print(<module_name>.__version__)
# ```

# %%
# Now run this code block on the kernel you just created
# Automatic script to install all required modules using Jupyter's built-in capabilities
import sys

required_modules = [
    "pyyaml",
    "numpy",
    "pandas",
    "matplotlib",
    "torch",
    "lightning",
    "wandb"
]

for module in required_modules:
    # !{sys.executable} -m pip install {module}
# Out:
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.2
# Collecting numpy
#   Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.6 MB 7.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.6 MB 9.9 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.6 MB 10.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 10.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.5
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 7.7 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.5 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.5 MB 11.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 10.6 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 9.2 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 9.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------------------------------- ---- 2.4/2.7 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 10.3 MB/s eta 0:00:00
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3
# Collecting torch
#   Downloading torch-2.7.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (4.13.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (78.1.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading torch-2.7.0-cp312-cp312-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 1.6/212.5 MB 7.6 MB/s eta 0:00:28
#     --------------------------------------- 3.7/212.5 MB 10.4 MB/s eta 0:00:21
#    - -------------------------------------- 6.6/212.5 MB 10.6 MB/s eta 0:00:20
#    - -------------------------------------- 9.2/212.5 MB 10.8 MB/s eta 0:00:19
#    -- ------------------------------------- 11.3/212.5 MB 10.7 MB/s eta 0:00:19
#    -- ------------------------------------- 13.4/212.5 MB 10.6 MB/s eta 0:00:19
#    --- ------------------------------------ 16.0/212.5 MB 10.8 MB/s eta 0:00:19
#    --- ------------------------------------ 18.4/212.5 MB 10.8 MB/s eta 0:00:18
#    --- ------------------------------------ 20.7/212.5 MB 10.8 MB/s eta 0:00:18
#    ---- ----------------------------------- 23.1/212.5 MB 10.9 MB/s eta 0:00:18
#    ---- ----------------------------------- 25.7/212.5 MB 10.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 28.0/212.5 MB 11.0 MB/s eta 0:00:17
#    ----- ---------------------------------- 30.7/212.5 MB 11.1 MB/s eta 0:00:17
#    ------ --------------------------------- 33.3/212.5 MB 11.1 MB/s eta 0:00:17
#    ------ --------------------------------- 35.4/212.5 MB 11.0 MB/s eta 0:00:17
#    ------- -------------------------------- 38.0/212.5 MB 11.0 MB/s eta 0:00:16
#    ------- -------------------------------- 40.4/212.5 MB 11.1 MB/s eta 0:00:16
#    ------- -------------------------------- 42.5/212.5 MB 11.1 MB/s eta 0:00:16
#    -------- ------------------------------- 44.8/212.5 MB 11.0 MB/s eta 0:00:16
#    -------- ------------------------------- 47.2/212.5 MB 11.0 MB/s eta 0:00:16
#    --------- ------------------------------ 49.8/212.5 MB 11.0 MB/s eta 0:00:15
#    --------- ------------------------------ 52.2/212.5 MB 11.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 54.5/212.5 MB 11.1 MB/s eta 0:00:15
#    ---------- ----------------------------- 57.1/212.5 MB 11.1 MB/s eta 0:00:15
#    ----------- ---------------------------- 59.5/212.5 MB 11.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 62.1/212.5 MB 11.1 MB/s eta 0:00:14
#    ------------ --------------------------- 64.5/212.5 MB 11.1 MB/s eta 0:00:14
#    ------------ --------------------------- 67.1/212.5 MB 11.1 MB/s eta 0:00:14
#    ------------- -------------------------- 69.5/212.5 MB 11.1 MB/s eta 0:00:13
#    ------------- -------------------------- 71.8/212.5 MB 11.1 MB/s eta 0:00:13
#    -------------- ------------------------- 74.4/212.5 MB 11.2 MB/s eta 0:00:13
#    -------------- ------------------------- 76.8/212.5 MB 11.2 MB/s eta 0:00:13
#    -------------- ------------------------- 79.4/212.5 MB 11.2 MB/s eta 0:00:12
#    --------------- ------------------------ 81.8/212.5 MB 11.2 MB/s eta 0:00:12
#    --------------- ------------------------ 83.9/212.5 MB 11.1 MB/s eta 0:00:12
#    ---------------- ----------------------- 86.2/212.5 MB 11.1 MB/s eta 0:00:12
#    ---------------- ----------------------- 88.6/212.5 MB 11.1 MB/s eta 0:00:12
#    ----------------- ---------------------- 91.2/212.5 MB 11.2 MB/s eta 0:00:11
#    ----------------- ---------------------- 93.6/212.5 MB 11.1 MB/s eta 0:00:11
#    ------------------ --------------------- 96.2/212.5 MB 11.1 MB/s eta 0:00:11
#    ------------------ --------------------- 98.6/212.5 MB 11.2 MB/s eta 0:00:11
#    ------------------ -------------------- 101.2/212.5 MB 11.2 MB/s eta 0:00:10
#    ------------------- ------------------- 103.5/212.5 MB 11.2 MB/s eta 0:00:10
#    ------------------- ------------------- 106.2/212.5 MB 11.2 MB/s eta 0:00:10
#    ------------------- ------------------- 108.3/212.5 MB 11.2 MB/s eta 0:00:10
#    -------------------- ------------------ 110.6/212.5 MB 11.2 MB/s eta 0:00:10
#    -------------------- ------------------ 112.7/212.5 MB 11.1 MB/s eta 0:00:09
#    --------------------- ----------------- 115.1/212.5 MB 11.1 MB/s eta 0:00:09
#    --------------------- ----------------- 117.4/212.5 MB 11.1 MB/s eta 0:00:09
#    --------------------- ----------------- 119.8/212.5 MB 11.1 MB/s eta 0:00:09
#    ---------------------- ---------------- 122.2/212.5 MB 11.1 MB/s eta 0:00:09
#    ---------------------- ---------------- 124.8/212.5 MB 11.1 MB/s eta 0:00:08
#    ----------------------- --------------- 127.4/212.5 MB 11.1 MB/s eta 0:00:08
#    ----------------------- --------------- 129.8/212.5 MB 11.2 MB/s eta 0:00:08
#    ------------------------ -------------- 132.4/212.5 MB 11.2 MB/s eta 0:00:08
#    ------------------------ -------------- 134.5/212.5 MB 11.2 MB/s eta 0:00:07
#    ------------------------- ------------- 137.1/212.5 MB 11.2 MB/s eta 0:00:07
#    ------------------------- ------------- 139.5/212.5 MB 11.2 MB/s eta 0:00:07
#    -------------------------- ------------ 141.8/212.5 MB 11.2 MB/s eta 0:00:07
#    -------------------------- ------------ 144.4/212.5 MB 11.2 MB/s eta 0:00:07
#    -------------------------- ------------ 146.8/212.5 MB 11.2 MB/s eta 0:00:06
#    --------------------------- ----------- 149.4/212.5 MB 11.2 MB/s eta 0:00:06
#    --------------------------- ----------- 151.8/212.5 MB 11.2 MB/s eta 0:00:06
#    ---------------------------- ---------- 153.9/212.5 MB 11.2 MB/s eta 0:00:06
#    ---------------------------- ---------- 156.0/212.5 MB 11.2 MB/s eta 0:00:06
#    ----------------------------- --------- 158.3/212.5 MB 11.2 MB/s eta 0:00:05
#    ----------------------------- --------- 161.0/212.5 MB 11.2 MB/s eta 0:00:05
#    ----------------------------- --------- 163.3/212.5 MB 11.2 MB/s eta 0:00:05
#    ------------------------------ -------- 165.9/212.5 MB 11.2 MB/s eta 0:00:05
#    ------------------------------ -------- 168.3/212.5 MB 11.2 MB/s eta 0:00:04
#    ------------------------------- ------- 170.9/212.5 MB 11.2 MB/s eta 0:00:04
#    ------------------------------- ------- 173.3/212.5 MB 11.2 MB/s eta 0:00:04
#    -------------------------------- ------ 175.6/212.5 MB 11.2 MB/s eta 0:00:04
#    -------------------------------- ------ 178.3/212.5 MB 11.2 MB/s eta 0:00:04
#    --------------------------------- ----- 180.6/212.5 MB 11.2 MB/s eta 0:00:03
#    --------------------------------- ----- 183.0/212.5 MB 11.2 MB/s eta 0:00:03
#    ---------------------------------- ---- 185.3/212.5 MB 11.2 MB/s eta 0:00:03
#    ---------------------------------- ---- 188.0/212.5 MB 11.2 MB/s eta 0:00:03
#    ---------------------------------- ---- 190.3/212.5 MB 11.2 MB/s eta 0:00:02
#    ----------------------------------- --- 192.7/212.5 MB 11.2 MB/s eta 0:00:02
#    ----------------------------------- --- 195.0/212.5 MB 11.2 MB/s eta 0:00:02
#    ------------------------------------ -- 197.7/212.5 MB 11.2 MB/s eta 0:00:02
#    ------------------------------------ -- 200.0/212.5 MB 11.2 MB/s eta 0:00:02
#    ------------------------------------- - 202.6/212.5 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------- - 205.0/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  207.6/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  210.0/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 11.2 MB/s eta 0:00:01
#    --------------------------------------- 212.5/212.5 MB 10.8 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.3 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 11.0 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.8 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch
#
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    --------------- ------------------------ 3/8 [MarkupSafe]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    ------------------------------ --------- 6/8 [jinja2]
#    ------------------------------ --------- 6/8 [jinja2]
#    ------------------------------ --------- 6/8 [jinja2]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ---------------------------------------- 8/8 [torch]
#
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 sympy-1.14.0 torch-2.7.0
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch>=2.1.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pytorch-lightning) (2.7.0)
# Collecting tqdm>=4.57.0 (from pytorch-lightning)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.4 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2025.3.2)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pytorch-lightning) (25.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pytorch-lightning) (4.13.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (78.1.1)
# Requirement already satisfied: filelock in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (1.14.0)
# Requirement already satisfied: networkx in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.4.2)
# Requirement already satisfied: jinja2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torchmetrics>=0.7.0->pytorch-lightning) (2.2.5)
# Requirement already satisfied: colorama in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from tqdm>=4.57.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ---------------------------------------- 0.0/823.1 kB ? eta -:--:--
#    ---------------------------------------- 823.1/823.1 kB 8.9 MB/s eta 0:00:00
# Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl (439 kB)
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ---------------------------------------- 0.0/961.5 kB ? eta -:--:--
#    ---------------------------------------- 961.5/961.5 kB 6.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, propcache, multidict, lightning-utilities, idna, frozenlist, attrs, aiohappyeyeballs, yarl, aiosignal, torchmetrics, aiohttp, pytorch-lightning
#
#    ----------------------------------------  0/13 [tqdm]
#    ------ ---------------------------------  2/13 [multidict]
#    --------- ------------------------------  3/13 [lightning-utilities]
#    ------------ ---------------------------  4/13 [idna]
#    ------------------ ---------------------  6/13 [attrs]
#    ------------------------ ---------------  8/13 [yarl]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    ------------------------------ --------- 10/13 [torchmetrics]
#    --------------------------------- ------ 11/13 [aiohttp]
#    --------------------------------- ------ 11/13 [aiohttp]
#    --------------------------------- ------ 11/13 [aiohttp]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ------------------------------------ --- 12/13 [pytorch-lightning]
#    ---------------------------------------- 13/13 [pytorch-lightning]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 attrs-25.3.0 frozenlist-1.6.0 idna-3.10 lightning-utilities-0.14.3 multidict-6.4.3 propcache-0.3.1 pytorch-lightning-2.5.1.post0 torchmetrics-1.7.1 tqdm-4.67.1 yarl-1.20.0
# Collecting wandb
#   Downloading wandb-0.19.11-py3-none-win_amd64.whl.metadata (10 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (4.3.8)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb)
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: psutil>=5.0.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (5.9.0)
# Collecting pydantic<3 (from wandb)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Requirement already satisfied: pyyaml in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (6.0.2)
# Collecting requests<3,>=2.0.0 (from wandb)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.27.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.6-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (78.1.1)
# Requirement already satisfied: typing-extensions<5,>=4.4 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (4.13.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb)
#   Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.0.0->wandb)
#   Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: idna<4,>=2.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.0.0->wandb)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.0.0->wandb)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: colorama in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.19.11-py3-none-win_amd64.whl (20.8 MB)
#    ---------------------------------------- 0.0/20.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.8/20.8 MB 8.4 MB/s eta 0:00:03
#    --------- ------------------------------ 4.7/20.8 MB 11.4 MB/s eta 0:00:02
#    ------------ --------------------------- 6.6/20.8 MB 10.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 8.4/20.8 MB 9.8 MB/s eta 0:00:02
#    ------------------- -------------------- 10.2/20.8 MB 9.7 MB/s eta 0:00:02
#    ------------------------ --------------- 12.6/20.8 MB 9.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 14.9/20.8 MB 9.9 MB/s eta 0:00:01
#    -------------------------------- ------- 17.0/20.8 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- -- 19.4/20.8 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 20.8/20.8 MB 9.8 MB/s eta 0:00:00
# Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 9.8 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl (105 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.27.0-py2.py3-none-any.whl (340 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading setproctitle-1.3.6-cp312-cp312-win_amd64.whl (12 kB)
# Installing collected packages: urllib3, typing-inspection, smmap, setproctitle, pydantic-core, protobuf, docker-pycreds, click, charset-normalizer, certifi, annotated-types, sentry-sdk, requests, pydantic, gitdb, gitpython, wandb
#
#    ----------------------------------------  0/17 [urllib3]
#    -- -------------------------------------  1/17 [typing-inspection]
#    --------- ------------------------------  4/17 [pydantic-core]
#    ----------- ----------------------------  5/17 [protobuf]
#    ----------- ----------------------------  5/17 [protobuf]
#    ----------- ----------------------------  5/17 [protobuf]
#    ---------------- -----------------------  7/17 [click]
#    ---------------- -----------------------  7/17 [click]
#    --------------------- ------------------  9/17 [certifi]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ------------------------- -------------- 11/17 [sentry-sdk]
#    ---------------------------- ----------- 12/17 [requests]
#    ------------------------------ --------- 13/17 [pydantic]
#    ------------------------------ --------- 13/17 [pydantic]
#    ------------------------------ --------- 13/17 [pydantic]
#    ------------------------------ --------- 13/17 [pydantic]
#    ------------------------------ --------- 13/17 [pydantic]
#    ------------------------------ --------- 13/17 [pydantic]
#    -------------------------------- ------- 14/17 [gitdb]
#    -------------------------------- ------- 14/17 [gitdb]
#    ----------------------------------- ---- 15/17 [gitpython]
#    ----------------------------------- ---- 15/17 [gitpython]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ------------------------------------- -- 16/17 [wandb]
#    ---------------------------------------- 17/17 [wandb]
#
# Successfully installed annotated-types-0.7.0 certifi-2025.4.26 charset-normalizer-3.4.2 click-8.1.8 docker-pycreds-0.4.0 gitdb-4.0.12 gitpython-3.1.44 protobuf-6.30.2 pydantic-2.11.4 pydantic-core-2.33.2 requests-2.32.3 sentry-sdk-2.27.0 setproctitle-1.3.6 smmap-5.0.2 typing-inspection-0.4.0 urllib3-2.4.0 wandb-0.19.11

# %% [markdown]
# Now we will test if everything worked...

# %%
import os
import math
import time
import shutil
import yaml

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader

import wandb

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.utilities.model_summary import ModelSummary

# Check if all imports worked
modules = [
    "os", "math", "time", "shutil", "yaml",
    "numpy", "pandas", "matplotlib.pyplot",
    "torch", "pytorch_lightning", "wandb"
]

failed_imports = []
for module in modules:
    try:
        exec(f"import {module}")
    except ImportError as e:
        failed_imports.append((module, str(e)))

if not failed_imports:
    print("All imports worked successfully!")
else:
    print("The following imports failed:")
    for module, error in failed_imports:
        print(f"{module}: {error}")
# Out:
# All imports worked successfully!

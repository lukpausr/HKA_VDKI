# %% [markdown]
# # Guide to Install Python and Required Modules
#
# ## Step 1: Install Anaconda
# 1. Setup python by installing Anaconda: [https://www.anaconda.com/download](https://www.anaconda.com/download).
# 2. Follow the installation instructions for your operating system.
#
# ## Step 2: Setup a anaconda environment
# 1. After installation, you can use the `conda` command to manage environments and packages.
# 2. To create a new environment using Python 3.12.3 named `VDKI-Projekt`, run the following command in your terminal or command prompt:

# %%
conda create --name VDKI-Projekt python=3.12.3

# %% [markdown]
# 3. Activate the environment using:

# %%
conda activate VDKI-Projekt

# %% [markdown]
# ## Step 3: Install Required Modules
# To install Python modules, you can run the script below. Be sure to allow the install of the ipynb-kernel within visual studio.

# %%
print("Lets run a line, visual studio will now ask you to install the ipynb-package")
# Out:
# Lets run a line, visual studio will now ask you to install the ipynb-package

# %% [markdown]
# ## Step 4: Verify Installation
# To verify that all required modules are installed we run the following python code below:
# ```python
# import <module_name>
# print(<module_name>.__version__)
# ```

# %%
# Now run this code block on the kernel you just created
# Automatic script to install all required modules using Jupyter's built-in capabilities
import sys

required_modules = [
    "pyyaml",
    "numpy",
    "pandas",
    "matplotlib",
    "torch",
    "lightning",
    "wandb",
    "scikit-image"
]

for module in required_modules:
    # !{sys.executable} -m pip install {module}
# Out:
# Requirement already satisfied: pyyaml in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (6.0.2)
# Requirement already satisfied: numpy in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (2.2.5)
# Requirement already satisfied: pandas in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: torch in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (2.7.0)
# Requirement already satisfied: filelock in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: lightning in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (2.5.1.post0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2025.3.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (0.14.3)
# Requirement already satisfied: packaging<25.0,>=20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (2.7.0)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (1.7.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (4.13.2)
# Requirement already satisfied: pytorch-lightning in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning) (2.5.1.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.18)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (78.1.1)
# Requirement already satisfied: filelock in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (1.14.0)
# Requirement already satisfied: networkx in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.4.2)
# Requirement already satisfied: jinja2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Requirement already satisfied: numpy>1.20.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from torchmetrics<3.0,>=0.7.0->lightning) (2.2.5)
# Requirement already satisfied: colorama in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.20.0)
# Requirement already satisfied: idna>=2.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from sympy>=1.13.3->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: wandb in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (0.19.11)
# Requirement already satisfied: click!=8.0.0,>=7.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (6.30.2)
# Requirement already satisfied: psutil>=5.0.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: pydantic<3 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (2.11.4)
# Requirement already satisfied: pyyaml in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (2.27.0)
# Requirement already satisfied: setproctitle in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (78.1.1)
# Requirement already satisfied: typing-extensions<5,>=4.4 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from wandb) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: colorama in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from scikit-image) (2.2.5)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: networkx>=3.0 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from scikit-image) (11.2.1)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in d:\programme\studium\anaconda\envs\vdki-projekt\lib\site-packages (from scikit-image) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.25.2-cp312-cp312-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.9 MB 8.4 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.9 MB 10.1 MB/s eta 0:00:01
#    --------------------- ------------------ 7.1/12.9 MB 11.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 10.8 MB/s eta 0:00:00
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/41.0 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/41.0 MB 11.4 MB/s eta 0:00:04
#    ------- -------------------------------- 7.3/41.0 MB 11.6 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/41.0 MB 11.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.1/41.0 MB 11.4 MB/s eta 0:00:03
#    -------------- ------------------------- 14.4/41.0 MB 11.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.0/41.0 MB 11.4 MB/s eta 0:00:03
#    ------------------ --------------------- 19.4/41.0 MB 11.3 MB/s eta 0:00:02
#    --------------------- ------------------ 21.8/41.0 MB 11.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.1/41.0 MB 11.4 MB/s eta 0:00:02
#    ------------------------- -------------- 26.5/41.0 MB 11.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 29.1/41.0 MB 11.4 MB/s eta 0:00:02
#    ------------------------------ --------- 31.5/41.0 MB 11.4 MB/s eta 0:00:01
#    --------------------------------- ------ 33.8/41.0 MB 11.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.2/41.0 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------- -- 38.8/41.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 11.0 MB/s eta 0:00:00
# Downloading tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Installing collected packages: tifffile, scipy, lazy-loader, imageio, scikit-image
#
#    ---------------------------------------- 0/5 [tifffile]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    ------------------------ --------------- 3/5 [imageio]
#    ------------------------ --------------- 3/5 [imageio]
#    ------------------------ --------------- 3/5 [imageio]
#    ------------------------ --------------- 3/5 [imageio]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    -------------------------------- ------- 4/5 [scikit-image]
#    ---------------------------------------- 5/5 [scikit-image]
#
# Successfully installed imageio-2.37.0 lazy-loader-0.4 scikit-image-0.25.2 scipy-1.15.3 tifffile-2025.3.30

# %% [markdown]
# Now we will test if everything worked...

# %%
import os
import math
import time
import shutil
import yaml

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader

import wandb

from skimage import io, transform

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.utilities.model_summary import ModelSummary

# Check if all imports worked
modules = [
    "os", "math", "time", "shutil", "yaml",
    "numpy", "pandas", "matplotlib.pyplot",
    "torch", "pytorch_lightning", "wandb", "skimage"
]

failed_imports = []
for module in modules:
    try:
        exec(f"import {module}")
    except ImportError as e:
        failed_imports.append((module, str(e)))

if not failed_imports:
    print("All imports worked successfully!")
else:
    print("The following imports failed:")
    for module, error in failed_imports:
        print(f"{module}: {error}")
# Out:
# All imports worked successfully!

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import torchvision.transforms as T
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torchvision.transforms.functional as F
import random
import math
import sys

# %% [markdown]
# ### Augmentation with balancing of classes

# %%
# Paths
source_dir = '/home/luka/Pictures/kaninchen_raw'
output_dir = '/home/luka/Pictures/kaninchen_aug'

# Constants
IMAGE_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp'}
valid_exts = ('.jpg', '.jpeg', '.png')
SPLITS = ['train', 'val', 'test']
RATIOS = {'train': 0.7, 'val': 0.15, 'test': 0.15}
random.seed(42)

# Augmentations
flip = T.RandomHorizontalFlip(p=1.0)

def rotate_crop_borders(img, angle):
    rotate_plus = T.RandomRotation(degrees=(angle, angle))
    img = rotate_plus(img)

    angle_deg = angle % 180
    if angle_deg > 90:
        angle_deg = 180 - angle_deg
    angle_rad = math.radians(angle_deg)

    sin_a = math.sin(angle_rad)
    cos_a = math.cos(angle_rad)

    if img.height * sin_a <= img.width * cos_a:
        new_w = (img.width * cos_a) - (img.height * sin_a)
        new_h = (img.height * cos_a) - (img.width * sin_a)
    else:
        new_w = (img.height * cos_a) - (img.width * sin_a)
        new_h = (img.width * cos_a) - (img.height * sin_a)

    if new_w <= 0 or new_h <= 0:
        return None

    left = (img.width - new_w) // 2
    top = (img.height - new_h) // 2
    right = left + new_w
    bottom = top + new_h

    if right <= left or bottom <= top:
        return None

    try:
        cropped_img = img.crop((left, top, right, bottom))
    except Exception:
        return None

    w, h = cropped_img.size
    if max(w, h) > 4 * min(w, h):
        return None

    return cropped_img

def get_class_files(class_path):
    return [f for f in os.listdir(class_path) if os.path.splitext(f)[1].lower() in IMAGE_EXTENSIONS]

def prepare_split_folders():
    for split in SPLITS:
        for class_name in os.listdir(source_dir):
            src_class_dir = os.path.join(source_dir, class_name)
            if os.path.isdir(src_class_dir):
                split_class_dir = os.path.join(output_dir, split, class_name)
                os.makedirs(split_class_dir, exist_ok=True)

def split_dataset():
    prepare_split_folders()

    for class_name in os.listdir(source_dir):
        src_class_dir = os.path.join(source_dir, class_name)
        if not os.path.isdir(src_class_dir):
            continue

        files = get_class_files(src_class_dir)
        if not files:
            continue

        # Split into train, val, test
        train_val, test = train_test_split(files, test_size=RATIOS['test'], random_state=42)
        train, val = train_test_split(train_val, test_size=RATIOS['val'] / (RATIOS['train'] + RATIOS['val']), random_state=42)
        split_map = {'train': train, 'val': val, 'test': test}

        for split in SPLITS:
            for f in split_map[split]:
                src = os.path.join(src_class_dir, f)
                dst = os.path.join(output_dir, split, class_name, f)
                shutil.copy2(src, dst)

def get_image_counts_per_split(split_root):
    image_counts = {}
    for class_name in os.listdir(split_root):
        class_path = os.path.join(split_root, class_name)
        if not os.path.isdir(class_path):
            continue
        count = len(get_class_files(class_path))
        image_counts[class_name] = count
    return image_counts

def augment_split(split):
    split_root = os.path.join(output_dir, split)
    image_counts = get_image_counts_per_split(split_root)

    class_names = list(image_counts.keys())
    max_img_count = max([v for k, v in image_counts.items() if k.lower() != 'other'])

    for class_name in class_names:
        class_path = os.path.join(split_root, class_name)
        files = get_class_files(class_path)
        current_count = image_counts[class_name]

        num_needed = max_img_count - current_count
        if num_needed <= 0:
            continue

        originals = []
        for file in files:
            path = os.path.join(class_path, file)
            name, ext = os.path.splitext(file)

            # Skip already augmented images
            if '_v' in name and name[-2:].isdigit():
                continue

            try:
                img = Image.open(path).convert("RGB")
                base_name = name
                if '_ok' in name:
                    base_name = name.split('_ok')[0] + '_ok'
                elif '_nok' in name:
                    base_name = name.split('_nok')[0] + '_nok'

                # Save v0 and delete original
                v0_name = f"{base_name}_v0{ext}"
                v0_path = os.path.join(class_path, v0_name)
                if not os.path.exists(v0_path):
                    img.save(v0_path)
                    os.remove(path)
                    print(f"[{split}] Saved _v0 and deleted original: {file}")
                originals.append((base_name, img))

            except Exception as e:
                print(f"[{split}] Failed to process {file}: {e}")

        # Augment each original with v1, v2, v3
        aug_count = 0
        for base_name, original in originals:
            if aug_count >= num_needed:
                break

            ext = ".jpg"  # standardize or detect from original

            # v1: flipped
            if aug_count < num_needed:
                try:
                    v1 = flip(original)
                    v1.save(os.path.join(class_path, f"{base_name}_v1{ext}"))
                    aug_count += 1
                except Exception as e:
                    print(f"[{split}] Failed to create v1 for {base_name}: {e}")

            # v2: rotated
            if aug_count < num_needed:
                try:
                    angle = random.uniform(5, 10)
                    v2 = rotate_crop_borders(original.copy(), angle)
                    if v2:
                        v2.save(os.path.join(class_path, f"{base_name}_v2{ext}"))
                        aug_count += 1
                except Exception as e:
                    print(f"[{split}] Failed to create v2 for {base_name}: {e}")

            # v3: rotated + flipped
            if aug_count < num_needed:
                try:
                    angle = random.uniform(5, 10)
                    rotated = rotate_crop_borders(original.copy(), angle)
                    if rotated:
                        v3 = flip(rotated)
                        v3.save(os.path.join(class_path, f"{base_name}_v3{ext}"))
                        aug_count += 1
                except Exception as e:
                    print(f"[{split}] Failed to create v3 for {base_name}: {e}")
def trim_other_class(split):
    split_root = os.path.join(output_dir, split)
    image_counts = get_image_counts_per_split(split_root)
    
    max_count = max([v for k, v in image_counts.items() if k.lower() != 'other'])
    other_path = os.path.join(split_root, 'other')

    if not os.path.exists(other_path):
        return

    other_images = [f for f in os.listdir(other_path) if f.lower().endswith(valid_exts)]
    if len(other_images) <= max_count:
        return

    # Randomly keep max_count files, delete rest
    to_keep = set(random.sample(other_images, max_count))
    for f in other_images:
        if f not in to_keep:
            try:
                os.remove(os.path.join(other_path, f))
                print(f"[{split}] Deleted extra from 'other': {f}")
            except Exception as e:
                print(f"[{split}] Failed to delete {f}: {e}")

def flatten_split_folders(base_output_dir):
    for split in ['train', 'val', 'test']:
        split_path = os.path.join(base_output_dir, split)
        if not os.path.exists(split_path):
            continue

        for class_name in os.listdir(split_path):
            class_folder = os.path.join(split_path, class_name)
            if not os.path.isdir(class_folder):
                continue

            for file in os.listdir(class_folder):
                src_file = os.path.join(class_folder, file)
                if not file.lower().endswith(valid_exts):
                    continue

                # Add class name prefix if not already present
                if not file.startswith(f"{class_name}_"):
                    new_name = f"{class_name}_{file}"
                else:
                    new_name = file

                dst_file = os.path.join(split_path, new_name)

                # Avoid overwriting files with the same name
                if os.path.exists(dst_file):
                    base, ext = os.path.splitext(new_name)
                    suffix = 1
                    while os.path.exists(os.path.join(split_path, f"{base}_{suffix}{ext}")):
                        suffix += 1
                    dst_file = os.path.join(split_path, f"{base}_{suffix}{ext}")

                try:
                    shutil.move(src_file, dst_file)
                except Exception as e:
                    print(f"[{split}] Failed to move {src_file} → {dst_file}: {e}")

            # Remove the now-empty class folder
            try:
                os.rmdir(class_folder)
                print(f"[{split}] Removed folder: {class_folder}")
            except Exception as e:
                print(f"[{split}] Could not remove folder {class_folder}: {e}")

split_dataset()


for split in SPLITS:
    print(f"\nAugmenting {split}...")
    augment_split(split)
    trim_other_class(split)

flatten_split_folders(output_dir)
print("\n✅ Done. Dataset split and augmented.")
# Out:
# Augmenting train...
# [train] Saved _v0 and deleted original: FullSizeRender-13_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-23_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5997_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8688_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_5458_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5986_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7026_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7048_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1248_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1231_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9735_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8691_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_6117_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9752_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1295_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-16_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1140_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7042_crop_1.JPEG
# [train] Saved _v0 and deleted original: ced93bda-7e5c-4134-a674-5fd56d22a707_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_4894_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6773_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8696_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_1225_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9747_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1116_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_1297_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1132_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9739_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1228_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8702_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_4827_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9776_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9771_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1294_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-36_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9786_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5730_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5948_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9731_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8686_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_1247_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1224_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9904_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9751_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9783_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6142_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1229_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9874_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9656_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6691_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4817_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6616_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1127_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5656_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5976_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8683_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9903_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_8684_crop_0.JPG
# [train] Saved _v0 and deleted original: FullSizeRender-29_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9657_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9746_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-54_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_9872_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-11_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8701_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8688_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_4804_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-55_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7091_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1233_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6611_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9871_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-8_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9654_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7049_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_6695_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6148_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9699_crop_0.JPG
# [train] Saved _v0 and deleted original: FullSizeRender-47_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5728_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1292_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9745_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8694_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9655_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9703_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9696_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_4893_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1167_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5460_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9780_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9732_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_7045_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9784_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9873_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6118_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7035_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_8689_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9923_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6128_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8693_crop_1.JPG
# [train] Saved _v0 and deleted original: FullSizeRender-67_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9730_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8686_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_6131_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1135_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5729_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5943_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5980_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-51_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8695_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1125_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-73_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9695_crop_0.JPG
# [train] Saved _v0 and deleted original: FullSizeRender-96_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9698_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8693_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8711_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_5459_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5660_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9727_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_6768_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5983_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1119_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_1232.jpg
# [train] Saved _v0 and deleted original: IMG_9753_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5945_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1296_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5939_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-120_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9729_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9736_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_4803_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6689_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9901_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1253_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8690_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_5733_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-102_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1134_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8691_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_7087_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7082_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9638_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-116_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1249_crop_0.jpg
# [train] Saved _v0 and deleted original: c095709c-10cf-4c84-8f38-127753b301da_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5979_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9700_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9754_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-84_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5659_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6765_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9779_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-25_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1230_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1129_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6694_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7028_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-26_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-97_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1138_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9906_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8692_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_8703_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1166_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_8698_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1291_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7046_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1270_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_0319_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2299_crop_0.JPEG
# [train] Saved _v0 and deleted original: 5c53dc0f-0508-40d1-966c-0687c8cdde7b_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1536_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1253_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2878_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0760_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_3075_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0935_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1252_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2877_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2334_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1520_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1286_crop_0.JPEG
# [train] Saved _v0 and deleted original: 23e8f94c-2935-470c-b2d9-5190ffbe21a3_crop_0.jpg
# [train] Saved _v0 and deleted original: bfeafcd7-b80a-448d-b083-2d0e95b86451_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0919_crop_0.JPEG
# [train] Saved _v0 and deleted original: 37178ef5-4c7f-461f-a680-3081d264b68d_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0759_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1269_crop_0.JPEG
# [train] Saved _v0 and deleted original: b7fd60bb-7adf-4912-8618-6b93c67c58dc_crop_0.jpg
# [train] Saved _v0 and deleted original: 6aca326b-f484-4c48-a8da-228914dd51d8_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0914_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0793_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0759_crop_0.JPEG
# [train] Saved _v0 and deleted original: 2fdf2f79-5ec5-43c6-be08-458e322cc59d_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0916_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4464_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2320_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0644_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_3072_crop_0.JPEG
# [train] Saved _v0 and deleted original: fb60dbec-072f-405a-9ca0-b872c7921122_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0761_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2291_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2303_crop_0.JPEG
# [train] Saved _v0 and deleted original: 14a893b5-b7c8-4bbd-810a-f5d350f9f68b_crop_0.jpg
# [train] Saved _v0 and deleted original: 84b13678-1a2d-414e-b6c7-e9823f8e2107_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0793-1_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0649_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1268_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0921_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9929_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9795_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1063_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8694_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_1251_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0678_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_0966_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9830_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-48_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1087_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_7046_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1112_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0717_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0565_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_2252_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9718_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1281_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9833_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9633_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9628_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1046_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9858_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_7021_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9836_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-39_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1057_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1049_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1113_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9792_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0847_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9680_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9799_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9612_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-117_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9795_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0562_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0955_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9797_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6108_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0708_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9855_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1124_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_4461_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9831_crop_0.JPEG
# [train] Saved _v0 and deleted original: 79db1bf1-3519-498a-a9fa-2bcd9655025b_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1222_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-74_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7042_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1006_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9683_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0783_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1288_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9677_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0560_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1577_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8710_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_7032_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1120_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9803_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-32_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1572_crop_0.JPEG
# [train] Saved _v0 and deleted original: 3c6b9c65-ccfe-445d-a341-63abec04fe51_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9930_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_6106_crop_1.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-113_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9620_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1221_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7019_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1246_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9616_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9686_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9632_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1289_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1117_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9845_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1002_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9851_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1219_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1056_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1217_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1027_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-18_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0785_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1087_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9691_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0677_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9692_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9617_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-20_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1109_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9927_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9849_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9670_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9619_crop_0.JPEG
# [train] Saved _v0 and deleted original: 3c109982-646b-4cd4-a59c-b830c9cc368c_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1114_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0680_crop_3.JPEG
# [train] Saved _v0 and deleted original: IMG_9611_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1252_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1047_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9937_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1026_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-30_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9622_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-19_crop_0.jpg
# [train] Saved _v0 and deleted original: 70278884-606d-49cc-81c2-8c6fa269e2d3_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9853_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0680_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9857_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1286_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9800_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7023_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9840_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-28_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-45_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7017_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9690_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7033_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9724_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9707_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_8684_crop_1.JPG
# [train] Saved _v0 and deleted original: FullSizeRender-95_crop_0.jpg
# [train] Saved _v0 and deleted original: c6cab999-b269-4f89-89cf-0c5b04511124_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1051_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9681_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0567_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9621_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1110_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1052_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9717_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9834_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9839_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9858_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9717_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_9624_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1220_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7020_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9794_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9615_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9618_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-86_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9842_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-80_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9675_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-49_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9694_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1062_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9673_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6055_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9687_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1283_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1119_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9803_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_0762_crop_0.JPEG
# [train] Saved _v0 and deleted original: 14a893b5-b7c8-4bbd-810a-f5d350f9f68b_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-46_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9722_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_3332_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9932_crop_1.JPG
# [train] Saved _v0 and deleted original: IMG_1218_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_9688_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0765_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9631_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9841_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0722_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9705_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9934_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1238_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1250_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6053_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6060_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9805_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1215_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9685_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9689_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1067_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0690_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1282_crop_0.jpg
# [train] Saved _v0 and deleted original: 15a4a4ad-8a6c-4339-8c0d-788669fb240c_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9927_crop_1.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-5_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7024_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9859_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9665_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-119_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1007_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9679_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-2_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9832_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9669_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1122_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9925_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0851_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7022_crop_2.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-82_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1277_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1121_crop_0.jpg
# [train] Saved _v0 and deleted original: b68ae11f-3d52-4458-a9f1-97d3d572e6cf_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-91_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9666_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9711_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_1045_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0849_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9793_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1053_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9835_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6105_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1115_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_0543_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_0665_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9613_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-61_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-53_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9926_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9610_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_0707_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9625_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1118_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9842_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1240_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9868_crop_0.JPEG
# [train] Saved _v0 and deleted original: befd47fa-d8c6-4457-8797-28d0be3e94c0_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9865_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9650_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6156_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1176_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6991_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5720_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9821_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-98_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-37_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9920_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1273_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1268_crop_0.jpg
# [train] Saved _v0 and deleted original: 30dc8ee5-767e-4f9b-b243-5b1d372dfb5d_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5818_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-33_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1259_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_9869_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1266_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6249_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4876_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9922_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6256_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6044_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7070_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-68_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1271_crop_1.jpg
# [train] Saved _v0 and deleted original: FullSizeRender_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-75_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7136_crop_2.JPEG
# [train] Saved _v0 and deleted original: IMG_9814_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6926_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9911_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5691_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4917_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7229_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9807_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-44_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-10_crop_0.jpg
# [train] Saved _v0 and deleted original: 5e0f7f01-170c-47da-a6ae-d9f74b827bd1_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6155_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-90_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9899_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-114_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1199_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-27_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9822_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7141_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9844_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9866_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1263_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5820_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-89_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7109_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9826_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4877_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_4848_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9914_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-88_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9907_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7231_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9908_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_8700_crop_0.JPG
# [train] Saved _v0 and deleted original: IMG_9892_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9810_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1265_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1256_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_7232_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9645_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7067_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9636_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5969_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1187.jpg
# [train] Saved _v0 and deleted original: IMG_1192.jpg
# [train] Saved _v0 and deleted original: IMG_9864_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9806_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9648_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9867_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9649_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-65_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1184.jpg
# [train] Saved _v0 and deleted original: IMG_9894_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-22_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5465_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5675_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1272_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9880_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1194_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6248_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9915_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9912_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7139_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1209_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9809_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4876_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1181_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9653_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1267_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9886_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4844_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5470_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7064_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1204_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1189_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9881_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_4830_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-59_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_4858_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1205_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1207_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6251_crop_0.JPEG
# [train] Saved _v0 and deleted original: 551719a7-93f8-4514-b36b-4fe82c6bb374_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9881_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1185_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9888_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-85.jpg
# [train] Saved _v0 and deleted original: IMG_9895_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6250_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5713_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6138_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5528_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4822_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9823_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-63_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-99_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9643_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9913_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1183_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1203_crop_0.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-64_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7108_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4838_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6923_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9846_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-104_crop_1.jpg
# [train] Saved _v0 and deleted original: IMG_1193.jpg
# [train] Saved _v0 and deleted original: IMG_1169_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1202_crop_1.jpg
# [train] Saved _v0 and deleted original: d61b4d4e-965d-41ba-9fd0-1faf25ee0569_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9817_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1173_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_4834_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1182_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9647_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9889_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4839_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-100_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5466_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1195_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_6989_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7144_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9843_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-70_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1279_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9909_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7066_crop_0.JPEG
# [train] Saved _v0 and deleted original: 8a70a08b-00de-4140-9189-01297d1afa42_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7068_crop_1.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-83_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5831_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9879_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1208_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1196_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_9808_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6927_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7106_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5521_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9893_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_5519_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_7098_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_4902_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1186_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7138_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_1274_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_4881_crop_1.JPEG
# [train] Saved _v0 and deleted original: IMG_9883_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-14_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_1278_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7103_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9646_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_6260_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_1269_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_7072_crop_0.JPEG
# [train] Saved _v0 and deleted original: FullSizeRender-75.jpg
# [train] Saved _v0 and deleted original: FullSizeRender-43_crop_0.jpg
# [train] Saved _v0 and deleted original: IMG_5610_crop_0.JPEG
# [train] Saved _v0 and deleted original: IMG_9910_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0461_crop_0.jpg
# [train] Deleted extra from 'other': Other_0603_crop_0.jpg
# [train] Deleted extra from 'other': Other_0390_crop_0.jpg
# [train] Deleted extra from 'other': Other_0576_crop_0.jpg
# [train] Deleted extra from 'other': Other_0023_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0145_crop_0.jpg
# [train] Deleted extra from 'other': Other_0188_crop_0.jpg
# [train] Deleted extra from 'other': Other_0218_crop_0.jpg
# [train] Deleted extra from 'other': Other_0683_crop_0.jpg
# [train] Deleted extra from 'other': Other_0272_crop_0.jpg
# [train] Deleted extra from 'other': Other_0565_crop_0.jpg
# [train] Deleted extra from 'other': Other_0240_crop_0.jpg
# [train] Deleted extra from 'other': Other_0617_crop_0.jpg
# [train] Deleted extra from 'other': Other_0064_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0451_crop_0.jpg
# [train] Deleted extra from 'other': Other_0449_crop_0.jpg
# [train] Deleted extra from 'other': Other_0685_crop_0.jpg
# [train] Deleted extra from 'other': Other_0154.jpg
# [train] Deleted extra from 'other': Other_0416.jpg
# [train] Deleted extra from 'other': Other_0583_crop_0.jpg
# [train] Deleted extra from 'other': Other_0464_crop_0.jpg
# [train] Deleted extra from 'other': Other_0185_crop_0.jpg
# [train] Deleted extra from 'other': Other_0666_crop_0.jpg
# [train] Deleted extra from 'other': Other_0358_crop_0.jpg
# [train] Deleted extra from 'other': Other_0670_crop_0.jpg
# [train] Deleted extra from 'other': Other_0159_crop_0.jpg
# [train] Deleted extra from 'other': Other_0638_crop_0.jpg
# [train] Deleted extra from 'other': Other_0532_crop_0.jpg
# [train] Deleted extra from 'other': Other_0139_crop_0.jpg
# [train] Deleted extra from 'other': Other_0066_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0057_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0094_crop_1.JPEG
# [train] Deleted extra from 'other': Other_0268_crop_0.jpg
# [train] Deleted extra from 'other': Other_0344_crop_0.jpg
# [train] Deleted extra from 'other': Other_0573_crop_0.jpg
# [train] Deleted extra from 'other': Other_0364_crop_0.jpg
# [train] Deleted extra from 'other': Other_0009_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0311_crop_0.jpg
# [train] Deleted extra from 'other': Other_0282_crop_0.jpg
# [train] Deleted extra from 'other': Other_0257_crop_0.jpg
# [train] Deleted extra from 'other': Other_0254_crop_0.jpg
# [train] Deleted extra from 'other': Other_0383_crop_0.jpg
# [train] Deleted extra from 'other': Other_0640_crop_0.jpg
# [train] Deleted extra from 'other': Other_0675_crop_0.jpg
# [train] Deleted extra from 'other': Other_0251_crop_0.jpg
# [train] Deleted extra from 'other': Other_0609_crop_0.jpg
# [train] Deleted extra from 'other': Other_0627_crop_0.jpg
# [train] Deleted extra from 'other': Other_0104_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0371_crop_0.jpg
# [train] Deleted extra from 'other': Other_0137_crop_0.jpg
# [train] Deleted extra from 'other': Other_0560_crop_0.jpg
# [train] Deleted extra from 'other': Other_0183_crop_0.jpg
# [train] Deleted extra from 'other': Other_0687_crop_0.jpg
# [train] Deleted extra from 'other': Other_0585_crop_0.jpg
# [train] Deleted extra from 'other': Other_0590_crop_0.jpg
# [train] Deleted extra from 'other': Other_0453_crop_0.jpg
# [train] Deleted extra from 'other': Other_0694_crop_0.jpg
# [train] Deleted extra from 'other': Other_0616_crop_0.jpg
# [train] Deleted extra from 'other': Other_0584_crop_0.jpg
# [train] Deleted extra from 'other': Other_0125_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0437_crop_0.jpg
# [train] Deleted extra from 'other': Other_0641_crop_1.jpg
# [train] Deleted extra from 'other': Other_0502_crop_0.jpg
# [train] Deleted extra from 'other': Other_0288_crop_0.jpg
# [train] Deleted extra from 'other': Other_0138_crop_1.jpg
# [train] Deleted extra from 'other': Other_0442_crop_0.jpg
# [train] Deleted extra from 'other': Other_0090.JPEG
# [train] Deleted extra from 'other': Other_0690_crop_0.jpg
# [train] Deleted extra from 'other': Other_0678_crop_0.jpg
# [train] Deleted extra from 'other': Other_0091_crop_2.JPEG
# [train] Deleted extra from 'other': Other_0490_crop_0.jpg
# [train] Deleted extra from 'other': Other_0017_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0655_crop_0.jpg
# [train] Deleted extra from 'other': Other_0375_crop_0.jpg
# [train] Deleted extra from 'other': Other_0581_crop_0.jpg
# [train] Deleted extra from 'other': Other_0324_crop_0.jpg
# [train] Deleted extra from 'other': Other_0511_crop_0.jpg
# [train] Deleted extra from 'other': Other_0181_crop_0.jpg
# [train] Deleted extra from 'other': Other_0682_crop_0.jpg
# [train] Deleted extra from 'other': Other_0361_crop_0.jpg
# [train] Deleted extra from 'other': Other_0399_crop_0.jpg
# [train] Deleted extra from 'other': Other_0328_crop_0.jpg
# [train] Deleted extra from 'other': Other_0447_crop_0.jpg
# [train] Deleted extra from 'other': Other_0322_crop_0.jpg
# [train] Deleted extra from 'other': Other_0484_crop_0.jpg
# [train] Deleted extra from 'other': Other_0677_crop_0.jpg
# [train] Deleted extra from 'other': Other_0202_crop_0.jpg
# [train] Deleted extra from 'other': Other_0281_crop_0.jpg
# [train] Deleted extra from 'other': Other_0129_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0650_crop_0.jpg
# [train] Deleted extra from 'other': Other_0319_crop_0.jpg
# [train] Deleted extra from 'other': Other_0559_crop_0.jpg
# [train] Deleted extra from 'other': Other_0176_crop_0.jpg
# [train] Deleted extra from 'other': Other_0563_crop_0.jpg
# [train] Deleted extra from 'other': Other_0692_crop_0.jpg
# [train] Deleted extra from 'other': Other_0314_crop_0.jpg
# [train] Deleted extra from 'other': Other_0394_crop_0.jpg
# [train] Deleted extra from 'other': Other_0594_crop_0.jpg
# [train] Deleted extra from 'other': Other_0071_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0312_crop_0.jpg
# [train] Deleted extra from 'other': Other_0528_crop_0.jpg
# [train] Deleted extra from 'other': Other_0296_crop_0.jpg
# [train] Deleted extra from 'other': Other_0421_crop_0.jpg
# [train] Deleted extra from 'other': Other_0047_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0356_crop_0.jpg
# [train] Deleted extra from 'other': Other_0575_crop_0.jpg
# [train] Deleted extra from 'other': Other_0148_crop_0.jpg
# [train] Deleted extra from 'other': Other_0203_crop_0.jpg
# [train] Deleted extra from 'other': Other_0589_crop_0.jpg
# [train] Deleted extra from 'other': Other_0633_crop_0.jpg
# [train] Deleted extra from 'other': Other_0085_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0475_crop_0.jpg
# [train] Deleted extra from 'other': Other_0374_crop_0.jpg
# [train] Deleted extra from 'other': Other_0411_crop_0.jpg
# [train] Deleted extra from 'other': Other_0458_crop_0.jpg
# [train] Deleted extra from 'other': Other_0448_crop_0.jpg
# [train] Deleted extra from 'other': Other_0418_crop_0.jpg
# [train] Deleted extra from 'other': Other_0463_crop_0.jpg
# [train] Deleted extra from 'other': Other_0396_crop_0.jpg
# [train] Deleted extra from 'other': Other_0149_crop_0.jpg
# [train] Deleted extra from 'other': Other_0228_crop_0.jpg
# [train] Deleted extra from 'other': Other_0214_crop_0.jpg
# [train] Deleted extra from 'other': Other_0481_crop_0.jpg
# [train] Deleted extra from 'other': Other_0245_crop_0.jpg
# [train] Deleted extra from 'other': Other_0386_crop_0.jpg
# [train] Deleted extra from 'other': Other_0237_crop_0.jpg
# [train] Deleted extra from 'other': Other_0433_crop_0.jpg
# [train] Deleted extra from 'other': Other_0354_crop_0.jpg
# [train] Deleted extra from 'other': Other_0093_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0230_crop_0.jpg
# [train] Deleted extra from 'other': Other_0607_crop_0.jpg
# [train] Deleted extra from 'other': Other_0592_crop_0.jpg
# [train] Deleted extra from 'other': Other_0423_crop_0.jpg
# [train] Deleted extra from 'other': Other_0350_crop_0.jpg
# [train] Deleted extra from 'other': Other_0514_crop_0.jpg
# [train] Deleted extra from 'other': Other_0216_crop_0.jpg
# [train] Deleted extra from 'other': Other_0323_crop_0.jpg
# [train] Deleted extra from 'other': Other_0053_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0557_crop_0.jpg
# [train] Deleted extra from 'other': Other_0143_crop_0.jpg
# [train] Deleted extra from 'other': Other_0527_crop_0.jpg
# [train] Deleted extra from 'other': Other_0130_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0208_crop_0.jpg
# [train] Deleted extra from 'other': Other_0541_crop_0.jpg
# [train] Deleted extra from 'other': Other_0408_crop_0.jpg
# [train] Deleted extra from 'other': Other_0337_crop_0.jpg
# [train] Deleted extra from 'other': Other_0016_crop_0.JPEG
# [train] Deleted extra from 'other': Other_0676_crop_0.jpg
# [train] Deleted extra from 'other': Other_0564_crop_0.jpg
# [train] Deleted extra from 'other': Other_0132.JPEG
# [train] Deleted extra from 'other': Other_0636_crop_0.jpg
# [train] Deleted extra from 'other': Other_0441_crop_0.jpg
# [train] Deleted extra from 'other': Other_0195_crop_0.jpg
# [train] Deleted extra from 'other': Other_0325_crop_0.jpg
# [train] Deleted extra from 'other': Other_0165_crop_0.jpg
# [train] Deleted extra from 'other': Other_0300_crop_0.jpg
# [train] Deleted extra from 'other': Other_0151_crop_0.jpg
# [train] Deleted extra from 'other': Other_0400_crop_0.jpg
# ...
# [val] Saved _v0 and deleted original: IMG_7074_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9862_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_1280_crop_0.jpg
# [val] Saved _v0 and deleted original: FullSizeRender-44_crop_1.jpg
# [val] Saved _v0 and deleted original: IMG_5649_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9818_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9919_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9863_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_5996_crop_0.JPEG
# [val] Saved _v0 and deleted original: FullSizeRender-56_crop_1.jpg
# [val] Saved _v0 and deleted original: IMG_1200.jpg
# [val] Saved _v0 and deleted original: IMG_1190_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_9887_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9825_crop_0.JPEG
# [val] Saved _v0 and deleted original: FullSizeRender-56_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_1174_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_9891_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9644_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_6254_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_1264_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_9652_crop_0.JPEG
# [val] Saved _v0 and deleted original: FullSizeRender-1_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_1258.jpg
# [val] Saved _v0 and deleted original: IMG_7093_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9812_crop_0.JPEG
# [val] Saved _v0 and deleted original: FullSizeRender-38_crop_1.jpg
# [val] Saved _v0 and deleted original: IMG_9898_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_9651_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_1198_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_4807_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_5469_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_6247_crop_0.JPEG
# [val] Saved _v0 and deleted original: IMG_4880_crop_1.JPEG
# [val] Saved _v0 and deleted original: IMG_1197_crop_0.jpg
# [val] Saved _v0 and deleted original: IMG_5530_crop_0.JPEG
# [val] Deleted extra from 'other': Other_0298_crop_0.jpg
# [val] Deleted extra from 'other': Other_0286_crop_0.jpg
# [val] Deleted extra from 'other': Other_0477_crop_0.jpg
# [val] Deleted extra from 'other': Other_0019_crop_0.JPEG
# [val] Deleted extra from 'other': Other_0586_crop_0.jpg
# [val] Deleted extra from 'other': Other_0076_crop_0.JPEG
# [val] Deleted extra from 'other': Other_0672_crop_0.jpg
# [val] Deleted extra from 'other': Other_0596_crop_0.jpg
# [val] Deleted extra from 'other': Other_0561_crop_0.jpg
# [val] Deleted extra from 'other': Other_0171_crop_0.jpg
# [val] Deleted extra from 'other': Other_0190_crop_0.jpg
# [val] Deleted extra from 'other': Other_0593_crop_0.jpg
# [val] Deleted extra from 'other': Other_0445_crop_0.jpg
# [val] Deleted extra from 'other': Other_0189_crop_0.jpg
# [val] Deleted extra from 'other': Other_0198_crop_0.jpg
# [val] Deleted extra from 'other': Other_0284_crop_1.jpg
# [val] Deleted extra from 'other': Other_0493.jpg
# [val] Deleted extra from 'other': Other_0519_crop_0.jpg
# [val] Deleted extra from 'other': IMG_1305_crop_0.jpg
# [val] Deleted extra from 'other': Other_0688_crop_0.jpg
# [val] Deleted extra from 'other': Other_0301_crop_0.jpg
# [val] Deleted extra from 'other': Other_0452_crop_0.jpg
# [val] Deleted extra from 'other': Other_0205_crop_0.jpg
# [val] Deleted extra from 'other': Other_0510_crop_0.jpg
# [val] Deleted extra from 'other': Other_0169_crop_0.jpg
# [val] Deleted extra from 'other': Other_0626_crop_0.jpg
# [val] Deleted extra from 'other': Other_0467_crop_0.jpg
# [val] Deleted extra from 'other': Other_0316_crop_0.jpg
# [val] Deleted extra from 'other': Other_0144_crop_0.jpg
# [val] Deleted extra from 'other': Other_0275_crop_0.jpg
# [val] Deleted extra from 'other': Other_0526_crop_0.jpg
# [val] Deleted extra from 'other': Other_0506.jpg
# [val] Deleted extra from 'other': Other_0020_crop_0.JPEG
# [val] Deleted extra from 'other': Other_0625_crop_0.jpg
# [val] Deleted extra from 'other': Other_0184_crop_0.jpg
# [val] Deleted extra from 'other': Other_0398_crop_0.jpg
# [val] Deleted extra from 'other': Other_0368_crop_0.jpg
# [val] Deleted extra from 'other': Other_0225_crop_0.jpg
#
# Augmenting test...
# [test] Saved _v0 and deleted original: FullSizeRender-74_crop_1.jpg
# [test] Saved _v0 and deleted original: IMG_1168_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1226_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1235_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-6_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_5658_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1223_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1162_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_7023_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9738_crop_0.JPG
# [test] Saved _v0 and deleted original: FullSizeRender-72_crop_1.jpg
# [test] Saved _v0 and deleted original: IMG_9733_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_9775_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_6615_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-41_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9750_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9777_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-108_crop_0.jpg
# [test] Saved _v0 and deleted original: 575854f6-8eb6-4bb5-a4c2-252d25007ee6_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-105_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1293_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9902_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1164_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_6756_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_8685_crop_0.JPG
# [test] Saved _v0 and deleted original: FullSizeRender-31_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-50_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_7220_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1133_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_6132_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9728_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_8692_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_7024_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-72_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9790_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1131_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_3073_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_6962_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_0775_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1268_crop_1.JPEG
# [test] Saved _v0 and deleted original: 6d430bb5-6611-4bc1-baf2-408229eb3856_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_2333_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_0945_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_0944_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_2876_crop_0.JPEG
# [test] Saved _v0 and deleted original: 7546223d-8e27-4112-8dcc-708edc908ca0_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9671_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1255_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-69_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-54_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_6058_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-3_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9934_crop_1.JPG
# [test] Saved _v0 and deleted original: IMG_1079_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_0720_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9715_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_1059_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9704_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_9668_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9626_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1574_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9678_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-7_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9801_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_3329_crop_0.JPEG
# [test] Saved _v0 and deleted original: 0bb321fe-286b-4564-8dcc-f0f6c348e7a8_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-94_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_7043_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9676_crop_0.JPEG
# [test] Saved _v0 and deleted original: 62369898-c295-49ea-b9c9-e34c7eff6d73_crop_0.jpg
# [test] Saved _v0 and deleted original: FullSizeRender-112_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9629_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9719_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_9802_crop_0.JPEG
# [test] Saved _v0 and deleted original: FullSizeRender-15_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9804_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9672_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1108_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9829_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_0540_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9614_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9723_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_9931_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_9796_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9667_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1078_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9683_crop_1.JPEG
# [test] Saved _v0 and deleted original: IMG_1253_crop_1.jpg
# [test] Saved _v0 and deleted original: IMG_7037_crop_1.JPEG
# [test] Saved _v0 and deleted original: IMG_7045_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1216_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9939_crop_0.JPG
# [test] Saved _v0 and deleted original: IMG_7035_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9635_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1188_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9860_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9861_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_6624_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1178_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9896_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_7230_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9870_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_4835_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1270_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9897_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9875_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_5666_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_6990_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1277_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_5467_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9890_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9921_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_5665_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9882_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1177_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_6929_crop_1.JPEG
# [test] Saved _v0 and deleted original: IMG_7104_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9813_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_9811_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1276_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9816_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_7094_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1171_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_7069_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_6930_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1172_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1257_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1201_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_9885_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_7143_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_7101_crop_0.JPEG
# [test] Saved _v0 and deleted original: IMG_1170_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1191_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_1275_crop_0.jpg
# [test] Saved _v0 and deleted original: IMG_6928_crop_0.JPEG
# [test] Deleted extra from 'other': Other_0419_crop_0.jpg
# [test] Deleted extra from 'other': Other_0276_crop_0.jpg
# [test] Deleted extra from 'other': Other_0611_crop_0.jpg
# [test] Deleted extra from 'other': Other_0223_crop_0.jpg
# [test] Deleted extra from 'other': Other_0370_crop_0.jpg
# [test] Deleted extra from 'other': Other_0333_crop_0.jpg
# [test] Deleted extra from 'other': Other_0639_crop_0.jpg
# [test] Deleted extra from 'other': Other_0387_crop_0.jpg
# [test] Deleted extra from 'other': Other_0554_crop_0.jpg
# [test] Deleted extra from 'other': Other_0401_crop_0.jpg
# [test] Deleted extra from 'other': Other_0620_crop_0.jpg
# [test] Deleted extra from 'other': Other_0162_crop_0.jpg
# [test] Deleted extra from 'other': Other_0637_crop_0.jpg
# [test] Deleted extra from 'other': Other_0485_crop_0.jpg
# [test] Deleted extra from 'other': Other_0339_crop_0.jpg
# [test] Deleted extra from 'other': Other_0317_crop_0.jpg
# [test] Deleted extra from 'other': Other_0373_crop_0.jpg
# [test] Deleted extra from 'other': Other_0117_crop_0.JPEG
# [test] Deleted extra from 'other': Other_0522_crop_0.jpg
# [test] Deleted extra from 'other': Other_0426_crop_0.jpg
# [test] Deleted extra from 'other': Other_0087_crop_0.JPEG
# [test] Deleted extra from 'other': IMG_1307_crop_0.jpg
# [test] Deleted extra from 'other': Other_0468_crop_0.jpg
# [test] Deleted extra from 'other': Other_0365_crop_0.jpg
# [test] Deleted extra from 'other': Other_0341_crop_0.jpg
# [test] Deleted extra from 'other': Other_0435_crop_0.jpg
# [test] Deleted extra from 'other': Other_0153_crop_0.jpg
# [test] Deleted extra from 'other': Other_0459_crop_0.jpg
# [test] Deleted extra from 'other': Other_0306_crop_0.jpg
# [test] Deleted extra from 'other': Other_0207_crop_0.jpg
# [test] Deleted extra from 'other': Other_0231_crop_0.jpg
# [test] Deleted extra from 'other': Other_0618_crop_0.jpg
# [test] Deleted extra from 'other': Other_0348_crop_0.jpg
# [test] Deleted extra from 'other': Other_0658_crop_0.jpg
# [test] Deleted extra from 'other': Other_0156_crop_0.jpg
# [test] Deleted extra from 'other': Other_0293_crop_0.jpg
# [test] Deleted extra from 'other': Other_0579_crop_0.jpg
# [test] Deleted extra from 'other': Other_0264_crop_0.jpg
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/Apollo
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/Nyx
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/Aster
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/other
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/Selene
# [train] Removed folder: /home/luka/Pictures/kaninchen_aug/train/Helios
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/Apollo
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/Nyx
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/Aster
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/other
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/Selene
# [val] Removed folder: /home/luka/Pictures/kaninchen_aug/val/Helios
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/Apollo
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/Nyx
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/Aster
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/other
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/Selene
# [test] Removed folder: /home/luka/Pictures/kaninchen_aug/test/Helios
#
# ✅ Done. Dataset split and augmented.

# %%
def print_flat_split_statistics(base_output_dir):
    print("Dataset statistics per split and class (from filename prefixes):\n")
    for split in SPLITS:
        split_path = os.path.join(base_output_dir, split)
        if not os.path.exists(split_path):
            print(f"{split}: folder does not exist.")
            continue
        class_counts = {}
        v0_counts = {}
        non_v0_counts = {}
        files = [f for f in os.listdir(split_path) if os.path.splitext(f)[1].lower() in IMAGE_EXTENSIONS]
        for f in files:
            prefix = f.split('_')[0]
            class_counts[prefix] = class_counts.get(prefix, 0) + 1
            if '_v0' in f:
                v0_counts[prefix] = v0_counts.get(prefix, 0) + 1
            else:
                non_v0_counts[prefix] = non_v0_counts.get(prefix, 0) + 1
        print(f"{split.capitalize()}:")
        for cname in sorted(class_counts.keys()):
            total = class_counts[cname]
            v0 = v0_counts.get(cname, 0)
            non_v0 = non_v0_counts.get(cname, 0)
            print(f"  {cname}: {total} (v0: {v0}, not v0: {non_v0})")
        print()

print_flat_split_statistics(output_dir)


# Print total number of images in the source directory (per class and overall)
def print_source_statistics(source_dir):
    print("Source dataset statistics per class:\n")
    total = 0
    for class_name in sorted(os.listdir(source_dir)):
        class_path = os.path.join(source_dir, class_name)
        if not os.path.isdir(class_path):
            continue
        count = len([f for f in os.listdir(class_path) if os.path.splitext(f)[1].lower() in IMAGE_EXTENSIONS])
        print(f"  {class_name}: {count}")
        total += count
    print(f"\nTotal images in source: {total}\n")

print_source_statistics(source_dir)

# Print total, v0, and not v0 numbers in output (all splits combined)
def print_output_totals(base_output_dir):
    total = 0
    v0_total = 0
    not_v0_total = 0
    for split in SPLITS:
        split_path = os.path.join(base_output_dir, split)
        if not os.path.exists(split_path):
            continue
        files = [f for f in os.listdir(split_path) if os.path.splitext(f)[1].lower() in IMAGE_EXTENSIONS]
        total += len(files)
        v0_total += sum(1 for f in files if '_v0' in f)
        not_v0_total += sum(1 for f in files if '_v0' not in f)
    print(f"Total images in output: {total} (v0: {v0_total}, not v0: {not_v0_total})\n")

print_output_totals(output_dir)

# Print per-class totals in output (all splits combined), including v0 / not v0
def print_output_class_totals(base_output_dir):
    class_totals = {}
    v0_class_totals = {}
    not_v0_class_totals = {}
    for split in SPLITS:
        split_path = os.path.join(base_output_dir, split)
        if not os.path.exists(split_path):
            continue
        files = [f for f in os.listdir(split_path) if os.path.splitext(f)[1].lower() in IMAGE_EXTENSIONS]
        for f in files:
            prefix = f.split('_')[0]
            class_totals[prefix] = class_totals.get(prefix, 0) + 1
            if '_v0' in f:
                v0_class_totals[prefix] = v0_class_totals.get(prefix, 0) + 1
            else:
                not_v0_class_totals[prefix] = not_v0_class_totals.get(prefix, 0) + 1
    print("Output totals per class (all splits combined):")
    for cname in sorted(class_totals.keys()):
        total = class_totals[cname]
        v0 = v0_class_totals.get(cname, 0)
        not_v0 = not_v0_class_totals.get(cname, 0)
        print(f"  {cname}: {total} (v0: {v0}, not v0: {not_v0})")
    print()

print_output_class_totals(output_dir)
# Out:
# Dataset statistics per split and class (from filename prefixes):
#
# Train:
#   Apollo: 293 (v0: 168, not v0: 125)
#   Aster: 168 (v0: 42, not v0: 126)
#   Helios: 293 (v0: 188, not v0: 105)
#   Nyx: 293 (v0: 0, not v0: 293)
#   Selene: 293 (v0: 220, not v0: 73)
#   other: 293 (v0: 0, not v0: 293)
#
# Val:
#   Apollo: 63 (v0: 36, not v0: 27)
#   Aster: 40 (v0: 10, not v0: 30)
#   Helios: 63 (v0: 41, not v0: 22)
#   Nyx: 63 (v0: 0, not v0: 63)
#   Selene: 63 (v0: 48, not v0: 15)
#   other: 63 (v0: 0, not v0: 63)
#
# Test:
#   Apollo: 63 (v0: 36, not v0: 27)
#   Aster: 40 (v0: 10, not v0: 30)
#   Helios: 63 (v0: 41, not v0: 22)
#   Nyx: 63 (v0: 0, not v0: 63)
#   Selene: 63 (v0: 48, not v0: 15)
#   other: 63 (v0: 0, not v0: 63)
#
# Source dataset statistics per class:
#
#   Apollo: 240
#   Aster: 62
#   Helios: 270
#   Nyx: 419
#   Selene: 316
#   other: 672
#
# Total images in source: 1979
#
# Total images in output: 2343 (v0: 888, not v0: 1455)
#
# Output totals per class (all splits combined):
#   Apollo: 419 (v0: 240, not v0: 179)
#   Aster: 248 (v0: 62, not v0: 186)
#   Helios: 419 (v0: 270, not v0: 149)
#   Nyx: 419 (v0: 0, not v0: 419)
#   Selene: 419 (v0: 316, not v0: 103)
#   other: 419 (v0: 0, not v0: 419)
